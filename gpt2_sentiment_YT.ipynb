# %% [markdown]
# # Tune GPT2 to generate positive reviews
# > Optimise GPT2 to produce positive IMDB movie reviews using a sentiment classifier as a reward function.

# %% [markdown]
# ### Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install transformers trl
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting trl
#   Downloading trl-0.7.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.1.0+cu121)
# Collecting accelerate (from trl)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 7.6 MB/s eta 0:00:00
# Collecting datasets (from trl)
#   Downloading datasets-2.16.0-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 13.9 MB/s eta 0:00:00
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.6.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.1.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->trl) (5.9.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (10.0.1)
# Collecting pyarrow-hotfix (from datasets->trl)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->trl)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (3.4.1)
# Collecting multiprocess (from datasets->trl)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (3.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->trl) (1.16.0)
# Installing collected packages: shtab, pyarrow-hotfix, docstring-parser, dill, multiprocess, tyro, accelerate, datasets, trl
# Successfully installed accelerate-0.25.0 datasets-2.16.0 dill-0.3.7 docstring-parser-0.15 multiprocess-0.70.15 pyarrow-hotfix-0.6 shtab-1.6.5 trl-0.7.7 tyro-0.6.2

# %%
import torch
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

from transformers import pipeline, AutoTokenizer
from datasets import load_dataset

from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead
from trl.core import LengthSampler

# %% [markdown]
# ### Configuration

# %%
config = PPOConfig(
    model_name="lvwerra/gpt2-imdb",
    learning_rate=1.41e-5,
)

sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 16}

# %% [markdown]
# ## Load data and models

# %% [markdown]
# ### Load IMDB dataset
# The IMDB dataset contains 50k movie review annotated with "positive"/"negative" feedback indicating the sentiment.  We load the IMDB dataset into a DataFrame and filter for comments that are at least 200 characters. Then we tokenize each text and cut it to random size with the `LengthSampler`.

# %%
def build_dataset(config, dataset_name="imdb", input_min_text_length=2, input_max_text_length=8):
    """
    Build dataset for training. This builds the dataset from `load_dataset`, one should
    customize this function to train the model on its own dataset.

    Args:
        dataset_name (`str`):
            The name of the dataset to be loaded.

    Returns:
        dataloader (`torch.utils.data.DataLoader`):
            The dataloader for the dataset.
    """
    tokenizer = AutoTokenizer.from_pretrained(config.model_name)
    tokenizer.pad_token = tokenizer.eos_token
    # load imdb with datasets
    ds = load_dataset(dataset_name, split="train")
    ds = ds.rename_columns({"text": "review"})
    ds = ds.filter(lambda x: len(x["review"]) > 200, batched=False)

    input_size = LengthSampler(input_min_text_length, input_max_text_length)

    def tokenize(sample):
        sample["input_ids"] = tokenizer.encode(sample["review"])[: input_size()]
        sample["query"] = tokenizer.decode(sample["input_ids"])
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")
    return ds

# %%
dataset = build_dataset(config)


def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])
# Out:
# tokenizer_config.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating unsupervised split: 0 examples [00:00, ? examples/s]
# Filter:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/24895 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ### Load pre-trained GPT2 language models

# %% [markdown]
# We load the GPT2 model with a value head and the tokenizer. We load the model twice; the first model is optimized while the second model serves as a reference to calculate the KL-divergence from the starting point. This serves as an additional reward signal in the PPO training to make sure the optimized model does not deviate too much from the original language model.

# %%
model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
ref_model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
tokenizer = AutoTokenizer.from_pretrained(config.model_name)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]

# %% [markdown]
# ### Initialize PPOTrainer
# The `PPOTrainer` takes care of device placement and optimization later on:

# %%
ppo_trainer = PPOTrainer(config, model, ref_model, tokenizer, dataset=dataset, data_collator=collator)

# %% [markdown]
# ### Load BERT classifier
# We load a BERT classifier fine-tuned on the IMDB dataset.

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"  # to avoid a `pipeline` bug
sentiment_pipe = pipeline("sentiment-analysis", model="lvwerra/distilbert-imdb", device=device)
# Out:
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# The model outputs are the logits for the negative and positive class. We will use the logits for positive class as a reward signal for the language model.

# %%
text = "this movie was really bad!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [[{'label': 'NEGATIVE', 'score': 2.3350484371185303},
#   {'label': 'POSITIVE', 'score': -2.726576328277588}]]

# %%
text = "this movie was really good!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# [[{'label': 'NEGATIVE', 'score': -2.294790267944336},
#   {'label': 'POSITIVE', 'score': 2.557040214538574}]]

# %% [markdown]
# ### Generation settings
# For the response generation we just use sampling and make sure top-k and nucleus sampling are turned off as well as a minimal length.

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %% [markdown]
# ## Optimize model

# %% [markdown]
# ### Training loop

# %% [markdown]
# The training loop consists of the following main steps:
# 1. Get the query responses from the policy network (GPT-2)
# 2. Get sentiments for query/responses from BERT
# 3. Optimize policy with PPO using the (query, response, reward) triplet

# %%
output_min_length = 4
output_max_length = 16
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


for epoch, batch in tqdm(enumerate(ppo_trainer.dataloader)):
    query_tensors = batch["input_ids"]

    #### Get response from gpt2
    response_tensors = []
    for query in query_tensors:
        gen_len = output_length_sampler()
        generation_kwargs["max_new_tokens"] = gen_len
        response = ppo_trainer.generate(query, **generation_kwargs)
        response_tensors.append(response.squeeze()[-gen_len:])
    batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]

    #### Compute sentiment score
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]

    #### Run PPO step
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# 0it [00:00, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 1it [02:25, 145.02s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (900.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (33.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (108.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (129.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (31.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (140.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (44.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (70.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (248.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1000.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (75.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (126.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (69.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (31.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (152.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (135.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (70.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (135.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (177.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (90.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (132.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1046.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (81.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (18.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (139.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 2it [04:21, 128.03s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (55.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (509.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (65.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (241.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (173.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (31.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (66.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (563.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (56.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (33.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (65.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (556.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (155.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (56.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 3it [06:22, 124.79s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (34.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (313.72) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (47.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (122.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (121.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (38.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (45.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (18.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (34.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (313.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (123.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (31.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (313.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (44.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (18.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (38.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 4it [08:20, 122.17s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (49.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (61.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (40.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (113.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (40.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (38.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (47.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (48.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (59.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (118.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (62.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (47.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (54.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (124.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 5it [10:18, 120.71s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (482.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (33.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (145.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (104.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (27.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (275.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (102.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (402.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (421.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (96.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (27.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (35.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (87.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (226.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (215.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (107.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (94.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (221.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (354.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (34.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (68.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (27.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (116.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (33.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (31.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (821.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 6it [12:18, 120.37s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (3393.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (968.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2974.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1932.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (939.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 7it [14:15, 119.43s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (199.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (39.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (34.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (18.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (34.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (52.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (212.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (53.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (34.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# ...
#   warnings.warn(
# 11it [22:09, 118.66s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (73.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1308.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (158.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (34.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (146.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (562.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (71.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1295.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (152.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (70.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (35.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (562.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1325.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 12it [24:12, 119.83s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (79.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (31.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (282.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 12it [25:14, 126.21s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-74e4bbd8a043> in <cell line: 15>()
#      31
#      32     #### Run PPO step
# ---> 33     stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
#      34     ppo_trainer.log_stats(stats, batch, rewards)
#
# /usr/lib/python3.10/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py in step(self, queries, responses, scores, response_masks)
#     786                         model_inputs = {k: mini_batch_dict[k] for k in model_inputs_names}
#     787
# --> 788                         logprobs, logits, vpreds, _ = self.batched_forward_pass(
#     789                             self.model,
#     790                             mini_batch_dict["queries"],
#
# /usr/lib/python3.10/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py in batched_forward_pass(self, model, queries, responses, model_inputs, return_logits, response_masks)
#     981             if response_masks is not None:
#     982                 response_masks_batch = response_masks[i * fbs : (i + 1) * fbs]
# --> 983             logits, _, values = model(**input_kwargs)
#     984
#     985             if self.is_encoder_decoder:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/trl/models/modeling_value_head.py in forward(self, input_ids, past_key_values, attention_mask, **kwargs)
#     167             kwargs.pop("past_key_values")
#     168
# --> 169         base_model_output = self.pretrained_model(
#     170             input_ids=input_ids,
#     171             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1072         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1073
# -> 1074         transformer_outputs = self.transformer(
#    1075             input_ids,
#    1076             past_key_values=past_key_values,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     886                 )
#     887             else:
# --> 888                 outputs = block(
#     889                     hidden_states,
#     890                     layer_past=layer_past,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     388         residual = hidden_states
#     389         hidden_states = self.ln_1(hidden_states)
# --> 390         attn_outputs = self.attn(
#     391             hidden_states,
#     392             layer_past=layer_past,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     329             attn_output, attn_weights = self._upcast_and_reordered_attn(query, key, value, attention_mask, head_mask)
#     330         else:
# --> 331             attn_output, attn_weights = self._attn(query, key, value, attention_mask, head_mask)
#     332
#     333         attn_output = self._merge_heads(attn_output, self.num_heads, self.head_dim)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gpt2/modeling_gpt2.py in _attn(self, query, key, value, attention_mask, head_mask)
#     210         # Downcast (if necessary) back to V's dtype (if in mixed-precision) -- No-Op otherwise
#     211         attn_weights = attn_weights.type(value.dtype)
# --> 212         attn_weights = self.attn_dropout(attn_weights)
#     213
#     214         # Mask heads if we want to
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
# -> 1521         forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1522         # If we don't have any hooks, we want to skip the rest of the logic in
#    1523         # this function, and just call forward.
#
# KeyboardInterrupt:

# %% [markdown]
# ## Model inspection
# Let's inspect some examples from the IMDB dataset. We can use `model_ref` to compare the tuned model `model` against the model before optimisation.

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /home/leandro/miniconda3/envs/trl/lib/python3.9/site-packages/transformers/pipelines/base.py:1075: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                    query  \
# 0                               Oh dear,
# 1                              I've seen
# 2                           Hi:<br /><br
# 3                           I'm a writer
# 4                                 If you
# 5                               OMG this
# 6                                   It's
# 7                      There is a really
# 8                                This is
# 9                                 Wasn't
# 10  This film is another of director Tim
# 11                  I thought this movie
# 12                 This early John Wayne
# 13                                 I was
# 14                     Embarrassingly, I
# 15                            I am a fan
#
#                                     response (before)  \
# 0        what are I saying?! I fast-forwarded through
# 1                                     it, as well.<br
# 2    />This movie is a turkey though when it comes to
# 3                    and I'm not going to be asked to
# 4    absolutely love sensitive romance, the plot a...
# 5              casting cast. Obi cult breezy, this is
# 6    unrealistic; the guy who was supposed to be E...
# 7             awful laptop game!<br /><br />I used to
# 8                              my favorite part about
# 9                     Wasn't it clichéd?<|endoftext|>
# 10                              Burton's masterpieces
# 11   was excellent. I actually laughed 6 times and...
# 12      films looked like an abandoned police beating
# 13           given an experience-a big one, almost 25
# 14   am more at a strict conformity after getting ...
# 15   of living on simple islands, and we have visi...
#
#                                      response (after)  rewards (before)  \
# 0       I must say that I are hanging my head on this         -0.858954
# 1              three million dialogue throughout, and          1.996807
# 2             />I also like that movie. It's so funny         -0.438191
# 3                  , not a screenwriter. I've written         -0.655991
# 4      are looking at the cinematography, the acting,          2.221309
# 5    movie was totally wonderful, I it was the ide...         -1.533139
# 6          a very good film. It reminds us about over         -2.097017
# 7    interesting story that set us the journey. Th...         -2.341743
# 8                                 a well thought well          2.554794
# 9    anyone else interested in this movie? It's a ...         -1.790802
# 10                                 Curry's best bombs          2.622917
# 11   was perfect, and I believe it's almost overlo...          2.548022
# 12              film is a realistic portrayal of what         -1.742279
# 13   very happy with all the reflections and this ...          2.250709
# 14   had never seen a movie before. There was one ...         -2.021666
# 15   of many things and learned how to appreciate ...          1.791297
#
#     rewards (after)
# 0         -1.007609
# 1          2.240883
# 2          2.415630
# 3         -0.724324
# 4          0.148751
# 5          2.590190
# 6          2.835831
# 7          2.282939
# 8          2.734139
# 9          2.631960
# 10         2.544106
# 11         2.601913
# 12         2.609762
# 13         2.558540
# 14        -1.803383
# 15         2.324461

# %% [markdown]
# Looking at the reward mean/median of the generated sequences we observe a significant difference.

# %% [markdown]
# ## Save model
# Finally, we save the model and push it to the Hugging Face for later usage.

# %%
model.save_pretrained("gpt2-imdb-pos-v2")
tokenizer.save_pretrained("gpt2-imdb-pos-v2")
# Out:
# ('gpt2-imdb-pos-v2/tokenizer_config.json',
#  'gpt2-imdb-pos-v2/special_tokens_map.json',
#  'gpt2-imdb-pos-v2/vocab.json',
#  'gpt2-imdb-pos-v2/merges.txt',
#  'gpt2-imdb-pos-v2/added_tokens.json',
#  'gpt2-imdb-pos-v2/tokenizer.json')

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !pip install -q gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 51.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.1/305.1 kB 33.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 34.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 42.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.8 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.

# %%
import gradio as gr

from transformers import pipeline
response = pipeline("text-generation", model="lvwerra/gpt2-imdb-pos-v2", device="cuda")

def get_positive_feedback(name):
  ##load the model
  output = response(name)
  return output

demo = gr.Interface(fn=get_positive_feedback, inputs="text", outputs="text")

if __name__ == "__main__":
    demo.launch(show_api=False)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://505391104f21f8fab9.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://505391104f21f8fab9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from transformers import pipeline
response = pipeline("text-generation", model="lvwerra/gpt2-imdb-pos-v2", device="cuda")
output = response("I hate how")
print(output)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "I hate how much I love this movie. It's a very good movie. It's a very"}]
